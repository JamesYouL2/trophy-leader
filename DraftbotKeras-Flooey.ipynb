# %%
import os
import json
import ast
import numpy as np
import pandas as pd
from collections import Counter
pd.set_option('display.max_colwidth', 900)

# %% [markdown]
# # Preprocessing

# %%
def parse_draft_to_standard_format(flooey_draft):
    draft = []
    for pack in flooey_draft['packs']:
        pack_list = []
        for pick in pack['picks']:
            cards = pick['cards']
            cards = sorted(cards, key=lambda x: x!=pick['pick'])
            pack_list.append(cards)
        draft.append(pack_list)
    return draft

# %%
draftsjson = json.load(open('iko.json'))
drafts = [parse_draft_to_standard_format(draft['Draft']) for draft in draftsjson]

# %% [markdown]
# # Create mapping between cards and integers

# %%
def get_cardset(drafts):
    cardset = set()
    for draft in drafts:
        for pack in draft:
            for pick in pack:
                for card in pick:
                    cardset.add(card)
    carddict = {card: i for i, card in enumerate(cardset)}
    return carddict

# %%
cardset = get_cardset(drafts)
invcardset = {v: k for k, v in cardset.items()}

# %%
len(drafts)
# Out:
# 1068

# %%
drafts[0]
# Out:
# [[['Umori, the Collector',
#    'Durable Coilbug',
#    'Greater Sandwurm',
#    'Flycatcher Giraffid',
#    'Light of Hope',
#    'Lurking Deadeye',
#    'Excavation Mole',
#    'Drannith Stinger',
#    'Of One Mind',
#    'Blade Banish',
#    'Blisterspit Gremlin',
#    'Channeled Force',
#    'Zagoth Crystal',
#    'Stormwild Capridor',
#    'Plains'],
#   ['Auspicious Starrix',
#    'Wilt',
#    'Boot Nipper',
#    'Convolute',
#    'Rumbling Rockslide',
#    'Pyroceratops',
#    'Ferocious Tigorilla',
#    'Essence Symbiote',
#    'Imposing Vantasaur',
#    'Crystacean',
#    'Corpse Churn',
#    'Chittering Harvester',
#    'Neutralize',
#    'Swamp'],
#   ['Parcelbeast',
#    'Plummet',
#    'Snare Tactician',
#    'Keep Safe',
#    'Corpse Churn',
#    'Blitz Leech',
#    'Thwart the Enemy',
#    'Crystacean',
#    'Evolving Wilds',
#    'Go for Blood',
#    'Easy Prey',
#    'Proud Wildbonder',
#    'Rugged Highlands'],
#   ['Ivy Elemental',
#    'Light of Hope',
#    'Evolving Wilds',
#    'Convolute',
#    'Dead Weight',
#    'Gust of Wind',
#    'Nightsquad Commando',
#    'Ferocious Tigorilla',
#    'Garrison Cat',
#    'Reptilian Reflection',
#    'Call of the Death-Dweller',
#    'Plains'],
#   ['Flycatcher Giraffid',
#    'Springjaw Trap',
#    'Mutual Destruction',
#    'Thwart the Enemy',
#    'Cloudpiercer',
#    'Pyroceratops',
#    'Maned Serval',
#    'Imposing Vantasaur',
#    'Essence Scatter',
#    'Migration Path',
#    'Dismal Backwater'],
#   ['Excavation Mole',
#    'Blazing Volley',
#    'Corpse Churn',
#    'Coordinated Charge',
#    'Lurking Deadeye',
#    'Dark Bargain',
#    'Imposing Vantasaur',
#    'Frost Lynx',
#    'Monstrous Step',
#    'Thornwood Falls'],
#   ['Greater Sandwurm',
#    'Coordinated Charge',
#    'Sudden Spinnerets',
#    'Adventurous Impulse',
#    'Frostveil Ambush',
#    'Raking Claws',
#    'Phase Dolphin',
#    'Neutralize',
#    'Scoured Barrens'],
#   ['Emergent Ultimatum',
#    'Springjaw Trap',
#    'Snare Tactician',
#    'Convolute',
#    'Raking Claws',
#    'Ferocious Tigorilla',
#    'Spontaneous Flight',
#    'Bloodfell Caves'],
#   ['Greater Sandwurm',
#    'Flycatcher Giraffid',
#    'Light of Hope',
#    'Excavation Mole',
#    'Blade Banish',
#    'Channeled Force',
#    'Plains'],
#   ['Imposing Vantasaur',
#    'Wilt',
#    'Convolute',
#    'Crystacean',
#    'Corpse Churn',
#    'Swamp'],
#   ['Plummet', 'Keep Safe', 'Corpse Churn', 'Thwart the Enemy', 'Crystacean'],
#   ['Garrison Cat', 'Light of Hope', 'Convolute', 'Plains'],
#   ['Migration Path', 'Thwart the Enemy', 'Maned Serval'],
#   ['Monstrous Step', 'Blazing Volley'],
#   ['Sudden Spinnerets']],
#  [['Fiend Artisan',
#    'Drannith Healer',
#    'Blade Banish',
#    'Unlikely Aid',
#    'Gust of Wind',
#    'Durable Coilbug',
#    'Excavation Mole',
#    'Suffocating Fumes',
#    'Blazing Volley',
#    'Springjaw Trap',
#    'Adaptive Shimmerer',
#    'Jubilant Skybonder',
#    'Will of the All-Hunter',
#    'Void Beckoner',
#    'Mountain'],
#   ['Jegantha, the Wellspring',
#    'Thieving Otter',
#    'Fertilid',
#    'Ferocious Tigorilla',
#    'Daysquad Marshal',
#    'Bristling Boar',
#    'Perimeter Sergeant',
#    'Greater Sandwurm',
#    'Essence Scatter',
#    'Savai Sabertooth',
#    'Mutual Destruction',
#    'Alert Heedbonder',
#    'Pouncing Shoreshark',
#    'Mountain'],
#   ['Trumpeting Gnarr',
#    'Adaptive Shimmerer',
#    'Gloom Pangolin',
#    'Lava Serpent',
#    'Lurking Deadeye',
#    'Light of Hope',
#    'Greater Sandwurm',
#    'Solid Footing',
#    'Capture Sphere',
#    'Spelleater Wolverine',
#    'Parcelbeast',
#    'Avian Oddity',
#    'Dismal Backwater'],
#   ['Hornbash Mentor',
#    'Humble Naturalist',
#    'Nightsquad Commando',
#    'Fully Grown',
#    'Lurking Deadeye',
#    'Gloom Pangolin',
#    'Perimeter Sergeant',
#    'Pyroceratops',
#    'Keep Safe',
#    'Sprite Dragon',
#    'Zenith Flare',
#    'Island'],
#   ['Parcelbeast',
#    'Essence Scatter',
#    'Frost Lynx',
#    'Unexpected Fangs',
#    'Thieving Otter',
#    'Glimmerbell',
#    'Sleeper Dart',
#    'Garrison Cat',
#    'Reptilian Reflection',
#    'Ketria Crystal',
#    'Blossoming Sands'],
#   ['Evolving Wilds',
#    'Spelleater Wolverine',
#    'Plummet',
#    'Drannith Stinger',
#    'Convolute',
#    'Frenzied Raptor',
#    'Momentum Rumbler',
#    'Migration Path',
#    'Sonorous Howlbonder',
#    'Forest'],
#   ['Parcelbeast',
#    'Exuberant Wolfbear',
#    'Crystacean',
#    'Fully Grown',
#    'Light of Hope',
#    'Wingfold Pteron',
#    'Titanoth Rex',
#    'Zagoth Crystal',
#    'Forest'],
#   ['Migratory Greathorn',
#    'Bushmeat Poacher',
#    'Evolving Wilds',
#    'Snare Tactician',
#    'Plummet',
#    'Wingfold Pteron',
#    'Indatha Crystal',
#    'Swiftwater Cliffs'],
#   ['Adaptive Shimmerer',
#    'Blade Banish',
#    'Unlikely Aid',
#    'Suffocating Fumes',
#    'Blazing Volley',
#    'Springjaw Trap',
#    'Mountain'],
#   ['Bristling Boar',
#    'Ferocious Tigorilla',
#    'Greater Sandwurm',
#    'Essence Scatter',
#    'Savai Sabertooth',
#    'Mountain'],
#   ['Greater Sandwurm',
#    'Adaptive Shimmerer',
#    'Gloom Pangolin',
#    'Light of Hope',
#    'Spelleater Wolverine'],
#   ['Gloom Pangolin', 'Pyroceratops', 'Keep Safe', 'Island'],
#   ['Frost Lynx', 'Sleeper Dart', 'Blossoming Sands'],
#   ['Frenzied Raptor', 'Forest'],
#   ['Forest']],
#  [['Humble Naturalist',
#    'Honey Mammoth',
#    'Springjaw Trap',
#    'Phase Dolphin',
#    'Blood Curdle',
#    'Suffocating Fumes',
#    'Divine Arrow',
#    'Go for Blood',
#    'Durable Coilbug',
#    'Adaptive Shimmerer',
#    'Cunning Nightbonder',
#    'Auspicious Starrix',
#    'Unbreakable Bond',
#    'Genesis Ultimatum',
#    'Scoured Barrens'],
#   ['Excavation Mole',
#    'Fire Prophecy',
#    'Blisterspit Gremlin',
#    'Frostveil Ambush',
#    'Light of Hope',
#    'Ferocious Tigorilla',
#    'Divine Arrow',
#    'Bushmeat Poacher',
#    'Capture Sphere',
#    'Cavern Whisperer',
#    'Call of the Death-Dweller',
#    'Sonorous Howlbonder',
#    'Inspired Ultimatum',
#    'Mountain'],
#   ['Dreamtail Heron',
#    'Blisterspit Gremlin',
#    'Gust of Wind',
#    'Adventurous Impulse',
#    'Snare Tactician',
#    'Cavern Whisperer',
#    'Plummet',
#    'Drannith Stinger',
#    'Checkpoint Officer',
#    'Dismal Backwater',
#    'Regal Leosaur',
#    'Neutralize',
#    'Swamp'],
#   ['Parcelbeast',
#    'Patagia Tiger',
#    'Startling Development',
#    'Facet Reader',
#    'Mosscoat Goriak',
#    'Raking Claws',
#    'Garrison Cat',
#    'Shredded Sails',
#    'Dark Bargain',
#    'Neutralize',
#    'Ketria Crystal',
#    'Island'],
#   ['Necropanther',
#    'Patagia Tiger',
#    'Springjaw Trap',
#    'Honey Mammoth',
#    'Heightened Reflexes',
#    'Anticipate',
#    'Blazing Volley',
#    'Nightsquad Commando',
#    'Blade Banish',
#    'Escape Protocol',
#    'Forest'],
#   ['Archipelagore',
#    'Unexpected Fangs',
#    "Survivors' Bond",
#    'Corpse Churn',
#    'Forbidden Friendship',
#    'Farfinder',
#    'Perimeter Sergeant',
#    'Frostveil Ambush',
#    'Insatiable Hemophage',
#    'Rugged Highlands'],
#   ['Dreamtail Heron',
#    'Solid Footing',
#    'Evolving Wilds',
#    'Unexpected Fangs',
#    'Honey Mammoth',
#    'Keep Safe',
#    'Lurking Deadeye',
#    'Majestic Auricorn',
#    'Wind-Scarred Crag'],
#   ['Avian Oddity',
#    'Mosscoat Goriak',
#    'Bristling Boar',
#    'Sleeper Dart',
#    'Dreamtail Heron',
#    'Maned Serval',
#    'Flycatcher Giraffid',
#    'Mountain'],
#   ['Phase Dolphin',
#    'Honey Mammoth',
#    'Springjaw Trap',
#    'Suffocating Fumes',
#    'Adaptive Shimmerer',
#    'Cunning Nightbonder',
#    'Genesis Ultimatum'],
#   ['Inspired Ultimatum',
#    'Frostveil Ambush',
#    'Light of Hope',
#    'Ferocious Tigorilla',
#    'Call of the Death-Dweller',
#    'Mountain'],
#   ['Neutralize',
#    'Gust of Wind',
#    'Adventurous Impulse',
#    'Snare Tactician',
#    'Swamp'],
#   ['Mosscoat Goriak', 'Facet Reader', 'Garrison Cat', 'Island'],
#   ['Escape Protocol', 'Blazing Volley', 'Forest'],
#   ['Rugged Highlands', 'Corpse Churn'],
#   ['Solid Footing']]]

# %% [markdown]
# # Convert drafts to vectors

# %%
def vectorize_drafts(drafts):
    cardset = get_cardset(drafts)
    flooey_drafts = [parse_draft_to_flooey_format(draft) for draft in drafts]
    return [vectorize_draft(draft, cardset) for draft in flooey_drafts]

def vectorize_draft(draft, cardset):
    draft_x = np.zeros([3, len(draft[0][0]), len(cardset) * 2])
    draft_y = np.zeros([3, len(draft[0][0]), len(cardset)])
    pile = np.zeros(len(cardset))
    for pa, pack in enumerate(draft):
        for pi, pick in enumerate(pack):
            draft_y[pa][pi][cardset.get(pick[0], -1)] = 1
            x1 = np.zeros(len(cardset))
            for card in pick:
                if card in cardset:
                    x1[cardset[card]] += 1
                else:
                    x1[-1] += 1
            draft_x[pa][pi] = np.append(x1, pile)
            pile[cardset.get(pick[0], -1)] += 1
            
    return {'draft_x': draft_x, 'draft_y': draft_y}

# %% [markdown]
# # Rudimentary train/test split

# %%
import random
random.shuffle(drafts)
split_no = int(len(drafts) * 0.8)
train = drafts[:split_no]
test = drafts[split_no:]
print(len(train), len(test))
# Out:
# 854 214

# %% [markdown]
# # Modeling

# %%
def DraftGenerator(trainset, batch_size=20):
    while True:
        for i in range(0, len(trainset) / batch_size):
            flooey_drafts = trainset[i*batch_size:(i+1)*batch_size]
            draftsv = [vectorize_draft(draft, cardset) for draft in flooey_drafts]
            X, Y = [], []
            for draft in draftsv:
                draft_x = draft['draft_x']
                draft_y = draft['draft_y']
                for pack in range(len(draft_x)):
                    for pick in range(len(draft_x[pack])):
                        Y.append(draft_y[pack][pick])
                        X.append(draft_x[pack][pick].flatten())
            yield (np.array(X), np.array(Y))

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout

# %%
model = Sequential()
model.add(Dense(
    512, activation='relu',
    input_dim=len(cardset) * 2
))
model.add(Dropout(0.5))
model.add(Dense(512))
model.add(Dropout(0.5))
model.add(Dense(len(cardset), activation='softmax'))
model.compile(
    optimizer='rmsprop',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
dg = DraftGenerator(train)

# %%
dg
# Out:
# <generator object DraftGenerator at 0x000002431F66F3B8>

# %%
batch_size = 20
model.fit(dg, steps_per_epoch=len(train) / batch_size, epochs=10)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-16-b89d27cb99ab> in <module>
#       1 batch_size = 20
# ----> 2 model.fit(dg, steps_per_epoch=len(train) / batch_size, epochs=10)
#
# C:\Python36\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1062           use_multiprocessing=use_multiprocessing,
#    1063           model=self,
# -> 1064           steps_per_execution=self._steps_per_execution)
#    1065
#    1066       # Container that configures and calls `tf.keras.Callback`s.
#
# C:\Python36\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1110         use_multiprocessing=use_multiprocessing,
#    1111         distribution_strategy=ds_context.get_strategy(),
# -> 1112         model=model)
#    1113
#    1114     strategy = ds_context.get_strategy()
#
# C:\Python36\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     777     # Since we have to know the dtype of the python generator when we build the
#     778     # dataset, we have to look at a batch to infer the structure.
# --> 779     peek, x = self._peek_and_restore(x)
#     780     peek = self._standardize_batch(peek)
#     781     peek = _process_tensorlike(peek)
#
# C:\Python36\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in _peek_and_restore(x)
#     834   @staticmethod
#     835   def _peek_and_restore(x):
# --> 836     peek = next(x)
#     837     return peek, itertools.chain([peek], x)
#     838
#
# StopIteration:

# %%
dgtest = DraftGenerator(test)

# %%
model.evaluate(dgtest, steps=len(test) / batch_size)[1]
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-19-290c754732c7> in <module>
# ----> 1 model.evaluate(dgtest, steps=len(test) / batch_size)[1]
#
# C:\Python36\lib\site-packages\tensorflow\python\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1364             use_multiprocessing=use_multiprocessing,
#    1365             model=self,
# -> 1366             steps_per_execution=self._steps_per_execution)
#    1367
#    1368       # Container that configures and calls `tf.keras.Callback`s.
#
# C:\Python36\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1110         use_multiprocessing=use_multiprocessing,
#    1111         distribution_strategy=ds_context.get_strategy(),
# -> 1112         model=model)
#    1113
#    1114     strategy = ds_context.get_strategy()
#
# C:\Python36\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     777     # Since we have to know the dtype of the python generator when we build the
#     778     # dataset, we have to look at a batch to infer the structure.
# --> 779     peek, x = self._peek_and_restore(x)
#     780     peek = self._standardize_batch(peek)
#     781     peek = _process_tensorlike(peek)
#
# C:\Python36\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in _peek_and_restore(x)
#     834   @staticmethod
#     835   def _peek_and_restore(x):
# --> 836     peek = next(x)
#     837     return peek, itertools.chain([peek], x)
#     838
#
# StopIteration:

# %% [markdown]
# # Show picks from some sample drafts

# %%
testv = [vectorize_draft(draft, cardset) for draft in test]
X, Y = [], []
for draft in testv:
    draft_x = draft['draft_x']
    draft_y = draft['draft_y']
    for pack in range(len(draft_x)):
        for pick in range(len(draft_x[pack])):
            Y.append(draft_y[pack][pick])
            X.append(draft_x[pack][pick].flatten())
test_y = np.array(Y)
test_x = np.array(X)

# %%
sum(sum(draft_x[0]))
# Out:
# 225.0

# %%
len(cardset)
# Out:
# 264

# %%
ypred = model.predict(test_x)
ypred = [invcardset[np.argmax(yp)] for yp in ypred]
ytrue = []
cards_list = []
for draft in test:
    for pack in draft:
        for pick in pack:
            ytrue.append(pick[0])
            cards_list.append(pick)
            #print(pick)
# Out:
#  Grown', 'Aegis Turtle', 'Adventurous Impulse', 'Nightsquad Commando', 'Unbreakable Bond']
# ['Forbidden Friendship', 'Cathartic Reunion', 'Sudden Spinnerets', 'Ram Through', 'Pyroceratops', 'Mountain']
# ['Savai Crystal', 'Whisper Squad', 'Gloom Pangolin', 'Perimeter Sergeant', 'Sonorous Howlbonder']
# ['Blazing Volley', 'Flycatcher Giraffid', 'Plummet', 'Island']
# ['Solid Footing', 'Fully Grown', 'Aegis Turtle']
# ['Thwart the Enemy', 'Forest']
# ['Mountain']
# ['Shark Typhoon', 'Spontaneous Flight', 'Corpse Churn', 'Ram Through', 'Blazing Volley', 'Garrison Cat', 'Gust of Wind', 'Patagia Tiger', 'Adventurous Impulse', 'Serrated Scorpion', 'Snare Tactician', 'Skull Prophet', 'Cunning Nightbonder', 'Fight as One', 'Dismal Backwater']
# ['Frostveil Ambush', 'Lurking Deadeye', 'Dark Bargain', 'Capture Sphere', 'Thieving Otter', 'Savai Sabertooth', 'Blazing Volley', 'Mosscoat Goriak', 'Unlikely Aid', 'Dreamtail Heron', 'Primal Empathy', 'Ivy Elemental', 'Unpredictable Cyclone', 'Blossoming Sands']
# ['Flame Spill', 'Blazing Volley', 'Prickly Marmoset', 'Mutual Destruction', 'Springjaw Trap', 'Gloom Pangolin', 'Ram Through', 'Dreamtail Heron', 'Imposing Vantasaur', 'Ferocious Tigorilla', 'Momentum Rumbler', 'Trumpeting Gnarr', 'Plains']
# ['Frostveil Ambush', 'Heightened Reflexes', 'Imposing Vantasaur', 'Unlikely Aid', 'Cloudpiercer', 'Keep Safe', 'Humble Naturalist', 'Facet Reader', 'Thornwood Falls', 'Barrier Breach', 'Indatha Triome', 'Jungle Hollow']
# ['Go for Blood', 'Corpse Churn', 'Raking Claws', 'Whisper Squad', 'Cavern Whisperer', 'Flycatcher Giraffid', 'Memory Leak', 'Blisterspit Gremlin', 'Zagoth Mamba', 'Escape Protocol', 'Island']
# ['Drannith Healer', 'Glimmerbell', 'Pacifism', 'Tentative Connection', 'Dark Bargain', 'Humble Naturalist', 'Phase Dolphin', 'Garrison Cat', 'Pollywog Symbiote', 'Swamp']
# ['Zagoth Mamba', 'Dark Bargain', 'Blazing Volley', 'Almighty Brushwagg', 'Anticipate', 'Humble Naturalist', 'Hornbash Mentor', "Titans' Nest", 'Blossoming Sands']
# ['Of One Mind', 'Unlikely Aid', 'Excavation Mole', 'Solid Footing', 'Spontaneous Flight', 'Anticipate', 'Maned Serval', 'Almighty Brushwagg']
# ['Serrated Scorpion', 'Spontaneous Flight', 'Corpse Churn', 'Blazing Volley', 'Garrison Cat', 'Gust of Wind', 'Patagia Tiger']
# ['Lurking Deadeye', 'Dark Bargain', 'Blazing Volley', 'Mosscoat Goriak', 'Unlikely Aid', 'Blossoming Sands']
# ['Springjaw Trap', 'Blazing Volley', 'Gloom Pangolin', 'Momentum Rumbler', 'Plains']
# ['Thornwood Falls', 'Heightened Reflexes', 'Unlikely Aid', 'Jungle Hollow']
# ['Escape Protocol', 'Blisterspit Gremlin', 'Island']
# ['Tentative Connection', 'Swamp']
# ['Blossoming Sands']
# ['Blood Curdle', 'Corpse Churn', 'Gloom Pangolin', 'Savai Sabertooth', 'Drannith Stinger', 'Plummet', 'Spelleater Wolverine', 'Of One Mind', 'Shredded Sails', 'Helica Glider', 'Flourishing Fox', 'Glowstone Recluse', "General's Enforcer", 'Umori, the Collector', 'Swiftwater Cliffs']
# ['Auspicious Starrix', 'Capture Sphere', 'Divine Arrow', 'Essence Symbiote', 'Durable Coilbug', 'Ferocious Tigorilla', 'Bushmeat Poacher', 'Anticipate', 'Perimeter Sergeant', 'Greater Sandwurm', 'Startling Development', 'Escape Protocol', 'Reptilian Reflection', 'Swamp']
# ['Dreamtail Heron', 'Zagoth Crystal', 'Wilt', 'Adventurous Impulse', 'Crystacean', 'Corpse Churn', 'Vulpikeet', 'Dead Weight', 'Prickly Marmoset', 'Glimmerbell', 'Necropanther', 'Unpredictable Cyclone', 'Plains']
# ['Ram Through', 'Capture Sphere', 'Dead Weight', 'Pacifism', 'Perimeter Sergeant', 'Suffocating Fumes', 'Facet Reader', 'Mutual Destruction', 'Imposing Vantasaur', 'Shredded Sails', 'Sanctuary Smasher', 'Plains']
# ['Mythos of Brokkos', 'Ferocious Tigorilla', 'Wingfold Pteron', 'Light of Hope', 'Sudden Spinnerets', 'Cavern Whisperer', 'Capture Sphere', 'Mosscoat Goriak', 'Whisper Squad', 'Primal Empathy', 'Mountain']
# ['Almighty Brushwagg', 'Blade Banish', 'Coordinated Charge', 'Raking Claws', 'Springjaw Trap', 'Savai Sabertooth', 'Ketria Crystal', 'Momentum Rumbler', 'Song of Creation', 'Mountain']
# ['Memory Leak', 'Sudden Spinnerets', 'Shredded Sails', 'Perimeter Sergeant', 'Lurking Deadeye', 'Huntmaster Liger', 'Will of the All-Hunter', 'Zirda, the Dawnwaker', 'Rugged Highlands']
# ['Evolving Wilds', 'Aegis Turtle', 'Fertilid', 'Blisterspit Gremlin', 'Keep Safe', 'Unexpected Fangs', 'Lead the Stampede', 'Rugged Highlands']
# ['Of One Mind', 'Corpse Churn', 'Gloom Pangolin', 'Savai Sabertooth', 'Plummet', 'Shredded Sails', 'Helica Glider']
# ['Greater Sandwurm', 'Ferocious Tigorilla', 'Anticipate', 'Perimeter Sergeant', 'Escape Protocol', 'Swamp']
# ['Wilt', 'Crystacean', 'Corpse Churn', 'Vulpikeet', 'Plains']
# ['Facet Reader', 'Perimeter Sergeant', 'Suffocating Fumes', 'Plains']
# ['Sudden Spinnerets', 'Mosscoat Goriak', 'Mountain']
# ['Savai Sabertooth', 'Mountain']
# ['Perimeter Sergeant']
# ['Voracious Greatshark', 'Springjaw Trap', 'Blazing Volley', 'Flycatcher Giraffid', 'Bristling Boar', 'Drannith Stinger', 'Vulpikeet', 'Ram Through', 'Unexpected Fangs', 'Shredded Sails', 'Aegis Turtle', 'Flame Spill', 'Unbreakable Bond', 'Zagoth Crystal', 'Swamp']
# ['Trumpeting Gnarr', 'Spelleater Wolverine', 'Forbidden Friendship', 'Suffocating Fumes', 'Eerie Ultimatum', 'Ram Through', 'Mutual Destruction', 'Anticipate', 'Migratory Greathorn', 'Blood Curdle', 'Dire Tactics', 'Proud Wildbonder', 'Hunted Nightmare', 'Thornwood Falls']
# ['Archipelagore', 'Frostveil Ambush', 'Tentative Connection', 'Fertilid', 'Pacifism', 'Cathartic Reunion', 'Serrated Scorpion', 'Mutual Destruction', 'Boot Nipper', 'Shredded Sails', 'Titanoth Rex', 'Porcuparrot', 'Swamp']
# ['Easy Prey', 'Lava Serpent', 'Blitz Leech', 'Frostveil Ambush', 'Startling Development', 'Capture Sphere', 'Excavation Mole', 'Blade Banish', 'Rumbling Rockslide', 'Whisper Squad', 'Majestic Auricorn', 'Island']
# ['Plummet', 'Of One Mind', 'Savai Sabertooth', 'Maned Serval', 'Adventurous Impulse', 'Prickly Marmoset', 'Corpse Churn', 'Light of Hope', 'Huntmaster Liger', 'Emergent Ultimatum', 'Wind-Scarred Crag']
# ['Thornwood Falls', 'Sudden Spinnerets', 'Spelleater Wolverine', 'Capture Sphere', 'Patagia Tiger', 'Gloom Pangolin', 'Gust of Wind', 'Serrated Scorpion', 'Thwart the Enemy', 'Drannith Magistrate']
# ['Zagoth Crystal', 'Pyroceratops', 'Spontaneous Flight', 'Serrated Scorpion', 'Aegis Turtle', 'Gloom Pangolin', 'Suffocating Fumes', 'Raugrin Crystal', 'Scoured Barrens']
# ['Jungle Hollow', 'Raking Claws', 'Nightsquad Commando', 'Almighty Brushwagg', 'Adaptive Shimmerer', 'Phase Dolphin', 'Daysquad Marshal', 'Dark Bargain']
# ['Zagoth Crystal', 'Springjaw Trap', 'Blazing Volley', 'Bristling Boar', 'Unexpected Fangs', 'Aegis Turtle', 'Swamp']
# ['Anticipate', 'Spelleater Wolverine', 'Eerie Ultimatum', 'Ram Through', 'Mutual Destruction', 'Proud Wildbonder']
# ['Fertilid', 'Tentative Connection', 'Serrated Scorpion', 'Mutual Destruction', 'Swamp']
# ['Excavation Mole', 'Lava Serpent', 'Majestic Auricorn', 'Island']
# ['Corpse Churn', 'Savai Sabertooth', 'Maned Serval']
# ['Thwart the Enemy', 'Sudden Spinnerets']
# ['Gloom Pangolin']
# ['Avian Oddity', 'Raking Claws', 'Thwart the Enemy', 'Flycatcher Giraffid', 'Pacifism', 'Lava Serpent', 'Perimeter Sergeant', 'Escape Protocol', 'Wilt', 'Plummet', 'Serrated Scorpion', 'Sanctuary Smasher', 'Frillscare Mentor', "Offspring's Revenge", 'Bloodfell Caves']
# ['Essence Symbiote', 'Boot Nipper', 'Checkpoint Officer', 'Solid Footing', 'Blisterspit Gremlin', 'Gloom Pangolin', 'Snare Tactician', 'Thwart the Enemy', 'Capture Sphere', 'Pyroceratops', 'Indatha Crystal', 'Flame Spill', 'Mythos of Brokkos', 'Island']
# ['Parcelbeast', 'Go for Blood', 'Blitz Leech', 'Coordinated Charge', 'Excavation Mole', 'Mosscoat Goriak', 'Thwart the Enemy', 'Humble Naturalist', 'Checkpoint Officer', 'Frost Lynx', 'Mutual Destruction', 'Sanctuary Smasher', 'Island']
# ['Boneyard Lurker', 'Evolving Wilds', 'Lava Serpent', 'Nightsquad Commando', 'Vulpikeet', 'Heightened Reflexes', 'Forbidden Friendship', 'Almighty Brushwagg', 'Of One Mind', 'Whisper Squad', 'Will of the All-Hunter', 'Wind-Scarred Crag']
# ['Dreamtail Heron', 'Gust of Wind', 'Ferocious Tigorilla', 'Forest', 'Coordinated Charge', 'Blade Banish', 'Adventurous Impulse', 'Bushmeat Poacher', 'Checkpoint Officer', 'Neutralize', 'Plains']
# ['Almighty Brushwagg', 'Bushmeat Poacher', 'Imposing Vantasaur', 'Go for Blood', 'Anticipate', 'Patagia Tiger', 'Unlikely Aid', 'Duskfang Mentor', 'Drannith Magistrate', 'Blossoming Sands']
# ['Indatha Triome', 'Boot Nipper', 'Of One Mind', 'Mysterious Egg', 'Springjaw Trap', 'Hampering Snare', 'Evolving Wilds', 'Call of the Death-Dweller', 'Island']
# ['Humble Naturalist', 'Pyroceratops', 'Of One Mind', 'Whisper Squad', 'Thwart the Enemy', 'Crystacean', 'Helica Glider', 'Blossoming Sands']
# ['Wilt', 'Thwart the Enemy', 'Perimeter Sergeant', 'Escape Protocol', 'Plummet', 'Serrated Scorpion', 'Bloodfell Caves']
# ['Mythos of Brokkos', 'Gloom Pangolin', 'Thwart the Enemy', 'Capture Sphere', 'Pyroceratops', 'Island']
# ['Humble Naturalist', 'Blitz Leech', 'Excavation Mole', 'Thwart the Enemy', 'Island']
# ['Almighty Brushwagg', 'Heightened Reflexes', 'Of One Mind', 'Wind-Scarred Crag']
# ['Adventurous Impulse', 'Forest', 'Plains']
# ['Bushmeat Poacher', 'Unlikely Aid']
# ['Island']
# ['Gemrazer', 'Tentative Connection', 'Boot Nipper', 'Cathartic Reunion', 'Gust of Wind', 'Helica Glider', 'Gloom Pangolin', 'Drannith Healer', 'Adaptive Shimmerer', 'Essence Symbiote', 'Frost Lynx', 'Jubilant Skybonder', 'Frillscare Mentor', 'Bastion of Remembrance', 'Forest']
# ['Blood Curdle', 'Excavation Mole', 'Helica Glider', 'Fertilid', 'Dark Bargain', 'Fire Prophecy', 'Serrated Scorpion', 'Adventurous Impulse', 'Humble Naturalist', 'Pyroceratops', 'Raugrin Crystal', 'Pollywog Symbiote', 'Emergent Ultimatum', 'Thornwood Falls']
# ['Farfinder', 'Helica Glider', 'Plummet', 'Serrated Scorpion', 'Cavern Whisperer', 'Drannith Stinger', 'Garrison Cat', 'Facet Reader', 'Evolving Wilds', 'Sprite Dragon', 'Lore Drakkis', 'Pollywog Symbiote', 'Swiftwater Cliffs']
# ['Ram Through', 'Coordinated Charge', 'Ferocious Tigorilla', 'Pyroceratops', 'Aegis Turtle', 'Divine Arrow', 'Blade Banish', 'Pacifism', 'Frillscare Mentor', 'Avian Oddity', 'Exuberant Wolfbear', 'Wind-Scarred Crag']
# ['Evolving Wilds', 'Aegis Turtle', 'Maned Serval', 'Cavern Whisperer', 'Tentative Connection', 'Helica Glider', 'Greater Sandwurm', 'Coordinated Charge', 'Fight as One', 'Lead the Stampede', 'Rugged Highlands']
# ['Charge of the Forever-Beast', 'Frenzied Raptor', 'Aegis Turtle', 'Raking Claws', 'Frostveil Ambush', 'Drannith Healer', 'Imposing Vantasaur', 'Sudden Spinnerets', 'Go for Blood', 'Swiftwater Cliffs']
# ['Rugged Highlands', 'Cloudpiercer', 'Keep Safe', 'Blazing Volley', 'Fully Grown', 'Divine Arrow', 'Solid Footing', 'Channeled Force', 'Raugrin Crystal']
# ['Parcelbeast', 'Bristling Boar', 'Blazing Volley', 'Thieving Otter', 'Gloom Pangolin', 'Avian Oddity', 'Colossification', 'Swamp']
# ['Frost Lynx', 'Tentative Connection', 'Gust of Wind', 'Helica Glider', 'Gloom Pangolin', 'Adaptive Shimmerer', 'Forest']
# ['Pollywog Symbiote', 'Excavation Mole', 'Helica Glider', 'Fertilid', 'Adventurous Impulse', 'Pyroceratops']
# ['Pollywog Symbiote', 'Helica Glider', 'Plummet', 'Serrated Scorpion', 'Swiftwater Cliffs']
# ['Avian Oddity', 'Pyroceratops', 'Aegis Turtle', 'Blade Banish']
# ['Greater Sandwurm', 'Aegis Turtle', 'Rugged Highlands']
# ['Aegis Turtle', 'Raking Claws']
# ['Keep Safe']
# ['Crystalline Giant', 'Evolving Wilds', 'Spelleater Wolverine', 'Pacifism', 'Mutual Destruction', 'Imposing Vantasaur', 'Springjaw Trap', 'Gust of Wind', 'Fully Grown', 'Plummet', 'Blazing Volley', 'Rooting Moloch', 'Grimdancer', 'Indatha Crystal', 'Swamp']
# ['Back for More', 'Spontaneous Flight', 'Boot Nipper', 'Thwart the Enemy', 'Blazing Volley', 'Startling Development', 'Garrison Cat', 'Hampering Snare', 'Farfinder', 'Bushmeat Poacher', 'Alert Heedbonder', 'Lead the Stampede', 'Narset of the Ancient Way', 'Scoured Barrens']
# ['Dirge Bat', 'Blood Curdle', "Survivors' Bond", 'Vulpikeet', 'Glimmerbell', 'Convolute', 'Heightened Reflexes', 'Fully Grown', 'Keep Safe', 'Aegis Turtle', 'Jubilant Skybonder', 'Heartless Act', 'Forest']
# ['Blood Curdle', 'Facet Reader', 'Bushmeat Poacher', 'Mutual Destruction', 'Pyroceratops', 'Whisper Squad', 'Light of Hope', 'Go for Blood', 'Adventurous Impulse', 'Barrier Breach', 'Pollywog Symbiote', 'Forest']
# ['Fertilid', 'Frostveil Ambush', 'Whisper Squad', 'Dead Weight', 'Frenzied Raptor', 'Blazing Volley', 'Plummet', 'Unlikely Aid', 'Blitz of the Thunder-Raptor', "Death's Oasis", 'Mountain']
# ['Dead Weight', 'Whisper Squad', 'Coordinated Charge', 'Solid Footing', 'Adventurous Impulse', 'Anticipate', 'Heightened Reflexes', 'Of One Mind', 'Monstrous Step', 'Forest']
# ['Sudden Spinnerets', 'Mysterious Egg', 'Solid Footing', 'Aegis Turtle', 'Frenzied Raptor', 'Serrated Scorpion', 'Convolute', 'Sanctuary Smasher', 'Mountain']
# ['Dismal Backwater', 'Unlikely Aid', 'Gust of Wind', 'Dark Bargain', 'Blade Banish', 'Frenzied Raptor', 'Easy Prey', 'Blitz of the Thunder-Raptor']
# ['Indatha Crystal', 'Mutual Destruction', 'Gust of Wind', 'Fully Grown', 'Plummet', 'Blazing Volley', 'Swamp']
# ['Lead the Stampede', 'Boot Nipper', 'Thwart the Enemy', 'Blazing Volley', 'Garrison Cat', 'Scoured Barrens']
# ['Glimmerbell', 'Fully Grown', 'Keep Safe', 'Aegis Turtle', 'Forest']
# ['Pollywog Symbiote', 'Facet Reader', 'Adventurous Impulse', 'Forest']
# ['Plummet', 'Unlikely Aid', 'Mountain']
# ['Adventurous Impulse', 'Forest']
# ['Mountain']
# ['Ram Through', 'Unlikely Aid', 'Pyroceratops', 'Mysterious Egg', 'Startling Development', 'Patagia Tiger', 'Lurking Deadeye', 'Snare Tactician', 'Tentative Connection', 'Keep Safe', 'Sprite Dragon', 'Will of the All-Hunter', 'Savai Thundermane', 'Mythos of Brokkos', 'Forest']
# ['Dead Weight', 'Of One Mind', 'Adventurous Impulse', 'Thwart the Enemy', 'Cloudpiercer', 'Almighty Brushwagg', 'Sudden Spinnerets', 'Maned Serval', 'Suffocating Fumes', 'Cunning Nightbonder', 'Zenith Flare', 'Porcuparrot', "Death's Oasis", 'Forest']
# ['Blossoming Sands', 'Boot Nipper', 'Crystacean', 'Mysterious Egg', 'Drannith Healer', 'Bristling Boar', 'Lava Serpent', 'Shredded Sails', 'Pyroceratops', 'Whisper Squad', 'Zenith Flare', 'Will of the All-Hunter', 'Reptilian Reflection']
# ['Jungle Hollow', 'Checkpoint Officer', 'Forbidden Friendship', "Survivors' Bond", 'Cavern Whisperer', 'Blazing Volley', 'Savai Sabertooth', 'Thieving Otter', 'Facet Reader', 'Wilt', 'Fully Grown', 'Weaponize the Monsters']
# ['Blossoming Sands', 'Frostveil Ambush', 'Dark Bargain', 'Prickly Marmoset', 'Tentative Connection', 'Whisper Squad', 'Patagia Tiger', 'Mosscoat Goriak', 'Serrated Scorpion', 'Raking Claws', 'Drannith Magistrate']
# ['Blitz Leech', 'Helica Glider', 'Glimmerbell', 'Wilt', 'Prickly Marmoset', 'Solid Footing', 'Blisterspit Gremlin', 'Fertilid', 'Unpredictable Cyclone', 'Island']
# ['Mutual Destruction', 'Aegis Turtle', 'Keep Safe', 'Crystacean', "Survivors' Bond", 'Savai Sabertooth', 'Cloudpiercer', 'Perimeter Sergeant', 'Mountain']
# ['Capture Sphere', 'Sudden Spinnerets', 'Patagia Tiger', 'Startling Development', 'Gloom Pangolin', 'Heightened Reflexes', 'Tentative Connection', 'Momentum Rumbler']
# ['Pyroceratops', 'Unlikely Aid', 'Mysterious Egg', 'Patagia Tiger', 'Tentative Connection', 'Keep Safe', 'Forest']
# ['Sudden Spinnerets', 'Adventurous Impulse', 'Thwart the Enemy', 'Maned Serval', 'Suffocating Fumes', 'Forest']
# ['Bristling Boar', 'Mysterious Egg', 'Shredded Sails', 'Pyroceratops', 'Whisper Squad']
# ['Wilt', "Survivors' Bond", 'Blazing Volley', 'Fully Grown']
# ['Mosscoat Goriak', 'Whisper Squad', 'Serrated Scorpion']
# ['Solid Footing', 'Island']
# ['Mountain']
# ['Snapdax, Apex of the Hunt', 'Boot Nipper', 'Perimeter Sergeant', 'Ferocious Tigorilla', 'Ram Through', 'Thieving Otter', 'Coordinated Charge', 'Frostveil Ambush', 'Cavern Whisperer', 'Fertilid', 'Dead Weight', 'Sanctuary Smasher', 'Pollywog Symbiote', 'Ketria Crystal', 'Dismal Backwater']
# ['Blade Banish', 'Keep Safe', 'Essence Symbiote', 'Cloudpiercer', 'Humble Naturalist', "Survivors' Bond", 'Bushmeat Poacher', 'Anticipate', 'Greater Sandwurm', 'Clash of Titans', 'Cunning Nightbonder', 'Stormwild Capridor', 'Skycat Sovereign', 'Mountain']
# ['Evolving Wilds', 'Maned Serval', 'Ram Through', 'Cavern Whisperer', 'Crystacean', 'Glimmerbell', 'Essence Symbiote', 'Raking Claws', 'Fully Grown', 'Barrier Breach', 'Blitz of the Thunder-Raptor', 'Regal Leosaur', 'Mountain']
# ['Ram Through', 'Imposing Vantasaur', 'Ferocious Tigorilla', "Survivors' Bond", 'Convolute', 'Frost Lynx', 'Shredded Sails', 'Savai Sabertooth', 'Serrated Scorpion', 'Exuberant Wolfbear', "Titans' Nest", 'Swamp']
# ['Heartless Act', 'Mysterious Egg', 'Thwart the Enemy', 'Corpse Churn', 'Shredded Sails', 'Blood Curdle', 'Anticipate', 'Fully Grown', 'Aegis Turtle', 'Jubilant Skybonder', 'Island']
# ['Greater Sandwurm', 'Cavern Whisperer', 'Nightsquad Commando', 'Tentative Connection', 'Solid Footing', 'Adaptive Shimmerer', 'Huntmaster Liger', 'Savai Crystal', 'Sonorous Howlbonder', 'Rugged Highlands']
# ['Boot Nipper', 'Flycatcher Giraffid', 'Adaptive Shimmerer', "Survivors' Bond", 'Solid Footing', 'Inspired Ultimatum', 'Reconnaissance Mission', 'Exuberant Wolfbear', 'Bloodfell Caves']
# ['Fertilid', 'Blazing Volley', 'Migratory Greathorn', 'Hampering Snare', 'Unexpected Fangs', 'Serrated Scorpion', 'Garrison Cat', 'Swamp']
# ['Boot Nipper', 'Perimeter Sergeant', 'Ferocious Tigorilla', 'Cavern Whisperer', 'Fertilid', 'Ketria Crystal', 'Dismal Backwater']
# ['Bushmeat Poacher', 'Keep Safe', "Survivors' Bond", 'Anticipate', 'Stormwild Capridor', 'Mountain']
# ['Fully Grown', 'Crystacean', 'Barrier Breach', 'Blitz of the Thunder-Raptor', 'Mountain']
# ["Titans' Nest", "Survivors' Bond", 'Serrated Scorpion', 'Swamp']
# ['Thwart the Enemy', 'Mysterious Egg', 'Island']
# ['Adaptive Shimmerer', 'Solid Footing']
# ["Survivors' Bond"]
# ['Gemrazer', 'Dark Bargain', 'Crystacean', 'Honey Mammoth', 'Flycatcher Giraffid', 'Essence Scatter', 'Shredded Sails', 'Snare Tactician', 'Cavern Whisperer', 'Drannith Healer', 'Checkpoint Officer', 'Skull Prophet', 'Will of the All-Hunter', 'Chittering Harvester', 'Forest']
# ['Back for More', 'Forbidden Friendship', 'Dead Weight', 'Fire Prophecy', 'Spontaneous Flight', 'Humble Naturalist', 'Aegis Turtle', 'Phase Dolphin', 'Solid Footing', 'Migratory Greathorn', 'Whisper Squad', 'Ominous Seas', 'Ivy Elemental', 'Plains']
# ['Trumpeting Gnarr', 'Lava Serpent', 'Cloudpiercer', 'Sudden Spinnerets', 'Springjaw Trap', 'Patagia Tiger', 'Imposing Vantasaur', 'Cathartic Reunion', 'Gloom Pangolin', 'Hampering Snare', 'Tentative Connection', 'Boon of the Wish-Giver', 'Swiftwater Cliffs']
# ['Rugged Highlands', 'Gloom Pangolin', 'Fully Grown', 'Shredded Sails', 'Savai Sabertooth', 'Essence Symbiote', 'Heightened Reflexes', 'Frenzied Raptor', 'Convolute', 'Lore Drakkis', 'Mythos of Illuna', 'Wind-Scarred Crag']
# ['Migratory Greathorn', 'Springjaw Trap', 'Facet Reader', 'Sleeper Dart', 'Gloom Pangolin', 'Maned Serval', 'Unexpected Fangs', 'Raking Claws', 'Cloudpiercer', 'Sanctuary Lockdown', 'Glowstone Recluse']
# ['Blitz Leech', 'Solid Footing', 'Mosscoat Goriak', 'Phase Dolphin', 'Unexpected Fangs', 'Sleeper Dart', 'Lava Serpent', 'Helica Glider', 'Ketria Crystal', 'Scoured Barrens']
# ['Patagia Tiger', 'Cloudpiercer', 'Startling Development', 'Frostveil Ambush', 'Thwart the Enemy', 'Coordinated Charge', 'Phase Dolphin', 'Labyrinth Raptor', 'Plains']
# ['Monstrous Step', 'Suffocating Fumes', 'Springjaw Trap', 'Blisterspit Gremlin', 'Serrated Scorpion', 'Nightsquad Commando', 'Sanctuary Lockdown', 'Swamp']
# ['Honey Mammoth', 'Dark Bargain', 'Crystacean', 'Flycatcher Giraffid', 'Shredded Sails', 'Will of the All-Hunter', 'Forest']
# ['Humble Naturalist', 'Aegis Turtle', 'Phase Dolphin', 'Solid Footing', 'Whisper Squad', 'Plains']
# ['Gloom Pangolin', 'Cloudpiercer', 'Sudden Spinnerets', 'Cathartic Reunion', 'Tentative Connection']
# ['Essence Symbiote', 'Fully Grown', 'Shredded Sails', 'Frenzied Raptor']
# ['Sleeper Dart', 'Gloom Pangolin', 'Unexpected Fangs']
# ['Unexpected Fangs', 'Solid Footing']
# ['Plains']

# %%
pick
# Out:
# ['Plains']

# %%
df = pd.DataFrame({
    'options': cards_list[:19000],
    #'predicted': ypred[:19000],
    'taken': ytrue[:19000]
})

# %%
df.iloc[:45]
# Out:
#                                                                                                                                                                                                                                                           options  \
# 0   [Alert Heedbonder, Spontaneous Flight, Gloom Pangolin, Fully Grown, Sleeper Dart, Essence Symbiote, Heightened Reflexes, Wingfold Pteron, Of One Mind, Pyroceratops, Essence Scatter, Momentum Rumbler, Migration Path, Ruinous Ultimatum, Swiftwater Cliffs]
# 1                        [Farfinder, Hampering Snare, Gloom Pangolin, Perimeter Sergeant, Springjaw Trap, Greater Sandwurm, Spontaneous Flight, Prickly Marmoset, Lava Serpent, Capture Sphere, Reconnaissance Mission, Unbreakable Bond, Migration Path, Forest]
# 2                                          [Drannith Healer, Coordinated Charge, Whisper Squad, Daysquad Marshal, Fertilid, Survivors' Bond, Thieving Otter, Cavern Whisperer, Of One Mind, Charge of the Forever-Beast, Barrier Breach, Footfall Crater, Plains]
# 3                                                    [Bushmeat Poacher, Aegis Turtle, Migratory Greathorn, Fully Grown, Snare Tactician, Greater Sandwurm, Heightened Reflexes, Hampering Snare, Patagia Tiger, Lore Drakkis, Majestic Auricorn, Thornwood Falls]
# 4                                                                           [Almighty Brushwagg, Maned Serval, Aegis Turtle, Crystacean, Spelleater Wolverine, Springjaw Trap, Daysquad Marshal, Corpse Churn, Frenzied Raptor, Ivy Elemental, Swiftwater Cliffs]
# 5                                                                                                       [Farfinder, Excavation Mole, Fully Grown, Convolute, Tentative Connection, Snare Tactician, Blade Banish, Capture Sphere, Wingfold Pteron, Jungle Hollow]
# 6                                                                                                                [Whisper Squad, Of One Mind, Tentative Connection, Maned Serval, Spelleater Wolverine, Mutual Destruction, Thwart the Enemy, Frost Lynx, Plains]
# 7                                                                                                                      [Sanctuary Lockdown, Blisterspit Gremlin, Fully Grown, Patagia Tiger, Durable Coilbug, Cloudpiercer, Stormwild Capridor, Blossoming Sands]
# 8                                                                                                                                             [Spontaneous Flight, Gloom Pangolin, Fully Grown, Sleeper Dart, Heightened Reflexes, Wingfold Pteron, Pyroceratops]
# 9                                                                                                                                                               [Perimeter Sergeant, Hampering Snare, Gloom Pangolin, Springjaw Trap, Spontaneous Flight, Forest]
# 10                                                                                                                                                                                [Daysquad Marshal, Coordinated Charge, Survivors' Bond, Barrier Breach, Plains]
# 11                                                                                                                                                                                              [Hampering Snare, Aegis Turtle, Fully Grown, Heightened Reflexes]
# 12                                                                                                                                                                                                                   [Daysquad Marshal, Maned Serval, Crystacean]
# 13                                                                                                                                                                                                                            [Fully Grown, Tentative Connection]
# 14                                                                                                                                                                                                                                                       [Plains]
# 15                                              [Pacifism, Sleeper Dart, Pyroceratops, Plummet, Blitz Leech, Fertilid, Imposing Vantasaur, Frost Lynx, Drannith Stinger, Maned Serval, Unbreakable Bond, Pouncing Shoreshark, Flame Spill, Zagoth Triome, Island]
# 16                                   [Drannith Healer, Prickly Marmoset, Garrison Cat, Thwart the Enemy, Of One Mind, Solid Footing, Evolving Wilds, Crystacean, Rumbling Rockslide, Durable Coilbug, Back for More, Avian Oddity, Titanoth Rex, Thornwood Falls]
# 17                                [Dead Weight, Excavation Mole, Whisper Squad, Adaptive Shimmerer, Wingfold Pteron, Startling Development, Mysterious Egg, Spelleater Wolverine, Blade Banish, Clash of Titans, Cunning Nightbonder, Pouncing Shoreshark, Swamp]
# 18                                                   [Jubilant Skybonder, Coordinated Charge, Suffocating Fumes, Startling Development, Serrated Scorpion, Garrison Cat, Essence Scatter, Wilt, Spontaneous Flight, Ivy Elemental, Cunning Nightbonder, Mountain]
# 19                                                                          [Daysquad Marshal, Corpse Churn, Blitz Leech, Suffocating Fumes, Anticipate, Adaptive Shimmerer, Mosscoat Goriak, Unbreakable Bond, Zagoth Crystal, Reconnaissance Mission, Mountain]
# 20                                                                                           [Mutual Destruction, Suffocating Fumes, Gust of Wind, Wilt, Adaptive Shimmerer, Snare Tactician, Cavern Whisperer, Regal Leosaur, Call of the Death-Dweller, Island]
# 21                                                                                            [Perimeter Sergeant, Frenzied Raptor, Serrated Scorpion, Coordinated Charge, Thwart the Enemy, Durable Coilbug, Ram Through, Blisterspit Gremlin, Rugged Highlands]
# 22                                                                                                                                     [Checkpoint Officer, Blazing Volley, Crystacean, Survivors' Bond, Dark Bargain, Springjaw Trap, Spontaneous Flight, Swamp]
# 23                                                                                                                                                                      [Maned Serval, Sleeper Dart, Pyroceratops, Plummet, Frost Lynx, Unbreakable Bond, Island]
# 24                                                                                                                                                                      [Garrison Cat, Thwart the Enemy, Of One Mind, Solid Footing, Crystacean, Thornwood Falls]
# 25                                                                                                                                                                                  [Whisper Squad, Wingfold Pteron, Mysterious Egg, Spelleater Wolverine, Swamp]
# 26                                                                                                                                                                                                             [Garrison Cat, Wilt, Spontaneous Flight, Mountain]
# 27                                                                                                                                                                                                                           [Corpse Churn, Anticipate, Mountain]
# 28                                                                                                                                                                                                                                         [Gust of Wind, Island]
# 29                                                                                                                                                                                                                                             [Thwart the Enemy]
# 30             [Easy Prey, Gust of Wind, Essence Symbiote, Sudden Spinnerets, Lurking Deadeye, Aegis Turtle, Lead the Stampede, Fire Prophecy, Migratory Greathorn, Lava Serpent, Garrison Cat, Monstrous Step, Stormwild Capridor, Whirlwind of Thought, Island]
# 31     [Void Beckoner, Durable Coilbug, Suffocating Fumes, Startling Development, Essence Symbiote, Unexpected Fangs, Wingfold Pteron, Migratory Greathorn, Prickly Marmoset, Garrison Cat, Aegis Turtle, Boneyard Lurker, Weaponize the Monsters, Tranquil Cove]
# 32                                               [Lavabrink Venturer, Tentative Connection, Nightsquad Commando, Blade Banish, Blisterspit Gremlin, Keep Safe, Cloudpiercer, Unexpected Fangs, Plummet, Raking Claws, Zagoth Mamba, Easy Prey, Wind-Scarred Crag]
# 33                                                        [Fight as One, Unexpected Fangs, Maned Serval, Honey Mammoth, Thwart the Enemy, Gloom Pangolin, Zenith Flare, Cavern Whisperer, Wingfold Pteron, Serrated Scorpion, Genesis Ultimatum, Bloodfell Caves]
# 34                                                                                        [Whisper Squad, Convolute, Sleeper Dart, Patagia Tiger, Of One Mind, Wilt, Savai Sabertooth, Suffocating Fumes, Spontaneous Flight, Splendor Mare, Cunning Nightbonder]
# 35                                                                                                  [General's Enforcer, Hampering Snare, Raking Claws, Checkpoint Officer, Forbidden Friendship, Evolving Wilds, Vulpikeet, Wilt, Fight as One, Scoured Barrens]
# 36                                                                                                                  [Coordinated Charge, Wingfold Pteron, Ram Through, Blitz Leech, Tentative Connection, Fertilid, Zagoth Crystal, Exuberant Wolfbear, Mountain]
# 37                                                                                                                            [Suffocating Fumes, Ram Through, Spontaneous Flight, Gust of Wind, Mysterious Egg, Adaptive Shimmerer, Necropanther, Jungle Hollow]
# 38                                                                                                                                         [Garrison Cat, Essence Symbiote, Sudden Spinnerets, Migratory Greathorn, Monstrous Step, Whirlwind of Thought, Island]
# 39                                                                                                                                                         [Garrison Cat, Startling Development, Essence Symbiote, Unexpected Fangs, Aegis Turtle, Tranquil Cove]
# 40                                                                                                                                                                           [Nightsquad Commando, Tentative Connection, Blisterspit Gremlin, Keep Safe, Plummet]
# 41                                                                                                                                                                                          [Maned Serval, Unexpected Fangs, Thwart the Enemy, Serrated Scorpion]
# 42                                                                                                                                                                                                           [Sleeper Dart, Savai Sabertooth, Spontaneous Flight]
# 43                                                                                                                                                                                                                                           [Fight as One, Wilt]
# 44                                                                                                                                                                                                                                                     [Mountain]
#
#                   taken
# 0      Alert Heedbonder
# 1             Farfinder
# 2       Drannith Healer
# 3      Bushmeat Poacher
# 4    Almighty Brushwagg
# 5             Farfinder
# 6         Whisper Squad
# 7    Sanctuary Lockdown
# 8    Spontaneous Flight
# 9    Perimeter Sergeant
# 10     Daysquad Marshal
# 11      Hampering Snare
# 12     Daysquad Marshal
# 13          Fully Grown
# 14               Plains
# 15             Pacifism
# 16      Drannith Healer
# 17          Dead Weight
# 18   Jubilant Skybonder
# 19     Daysquad Marshal
# 20   Mutual Destruction
# 21   Perimeter Sergeant
# 22   Checkpoint Officer
# 23         Maned Serval
# 24         Garrison Cat
# 25        Whisper Squad
# 26         Garrison Cat
# 27         Corpse Churn
# 28         Gust of Wind
# 29     Thwart the Enemy
# 30            Easy Prey
# 31        Void Beckoner
# 32   Lavabrink Venturer
# 33         Fight as One
# 34        Whisper Squad
# 35   General's Enforcer
# 36   Coordinated Charge
# 37    Suffocating Fumes
# 38         Garrison Cat
# 39         Garrison Cat
# 40  Nightsquad Commando
# 41         Maned Serval
# 42         Sleeper Dart
# 43         Fight as One
# 44             Mountain

# %%
df.iloc[45:90]
# Out:
#                                                                                                                                                                                                                                                                  options  \
# 45   [Chemister's Insight, Fearless Halberdier, Skyknight Legionnaire, Urban Utopia, Spinal Centipede, Mephitic Vapors, Dimir Locket, Golgari Locket, Candlelight Vigil, Hypothesizzle, Muse Drake, Invert/Invent, Justice Strike, Deafening Clarion, Golgari Guildgate]
# 46                      [Underrealm Lich, Never Happened, Gravitic Punch, Rhizome Lurcher, Barging Sergeant, Vedalken Mesmerist, Crushing Canopy, Ledev Guardian, Loxodon Restorer, Maniacal Rage, Ornery Goblin, Flower/Flourish, Truefire Captain, Selesnya Guildgate]
# 47                                   [Hatchery Spider, Hunted Witness, Sworn Companions, Hired Poisoner, Rubblebelt Boar, Passwall Adept, Dazzling Lights, Selesnya Locket, Hitchclaw Recluse, Fearless Halberdier, Might of the Masses, Book Devourer, Dimir Guildgate]
# 48                                                             [Status/Statue, Leapfrog, Pitiless Gorgon, Barrier of Bones, Erstwhile Trooper, Dimir Informant, Dead Weight, Goblin Electromancer, Sure Strike, Justice Strike, Discovery/Dispersal, Selesnya Guildgate]
# 49                                                                                     [Whisper Agent, Wishcoin Crab, Wall of Mist, Veiled Shade, Dimir Informant, Ledev Guardian, Selesnya Locket, Prey Upon, Inescapable Blaze, Wand of Vertebrae, Selesnya Guildgate]
# 50                                                                                            [Darkblade Agent, Collar the Culprit, Wild Ceratok, Intrusive Packbeast, Barrier of Bones, Crushing Canopy, Passwall Adept, Prey Upon, Wand of Vertebrae, Boros Guildgate]
# 51                                                                                                                    [Golgari Guildgate, Pack's Favor, Torch Courier, Undercity Uprising, Child of Night, Veiled Shade, Leapfrog, Undercity Necrolisk, Golgari Raiders]
# 52                                                                                                                              [Gateway Plaza, Wary Okapi, Vicious Rumors, Piston-Fist Cyclops, Undercity Uprising, Garrison Sergeant, Generous Stray, Izzet Guildgate]
# 53                                                                                                                                                  [Mephitic Vapors, Fearless Halberdier, Urban Utopia, Dimir Locket, Golgari Locket, Candlelight Vigil, Invert/Invent]
# 54                                                                                                                                                               [Crushing Canopy, Never Happened, Gravitic Punch, Vedalken Mesmerist, Ledev Guardian, Loxodon Restorer]
# 134                                                                                                                                                                                                                                                   [Selesnya Locket]
#
#                      predicted                      taken
# 90         Experimental Frenzy        Experimental Frenzy
# 91           Niv-Mizzet, Parun          Niv-Mizzet, Parun
# 92           Sinister Sabotage          Sinister Sabotage
# 93              Capture Sphere  Unexplained Disappearance
# 94             Artful Takedown            Dimir Informant
# 95             Izzet Guildgate            Izzet Guildgate
# 96               Hypothesizzle              Hypothesizzle
# 97                 Notion Rain                Notion Rain
# 98               Hypothesizzle              Hypothesizzle
# 99            Barging Sergeant           Barging Sergeant
# 100             Hellkite Whelp             Hellkite Whelp
# 101           Cosmotronic Wave           Cosmotronic Wave
# 102                Notion Rain                Notion Rain
# 103             Gravitic Punch             Gravitic Punch
# 104       Pause for Reflection       Pause for Reflection
# 105                  Lava Coil                  Lava Coil
# 106             Direct Current             Direct Current
# 107              Hypothesizzle              Hypothesizzle
# 108        Piston-Fist Cyclops        Piston-Fist Cyclops
# 109          Runaway Steam-Kin          Runaway Steam-Kin
# 110            Izzet Guildgate            Izzet Guildgate
# 111        Piston-Fist Cyclops        Piston-Fist Cyclops
# 112            Izzet Guildgate              Ornery Goblin
# 113             Capture Sphere             Capture Sphere
# 114  Unexplained Disappearance  Unexplained Disappearance
# 115           Devious Cover-Up           Devious Cover-Up
# 116             Hellkite Whelp             Hellkite Whelp
# 117              Wishcoin Crab              Wishcoin Crab
# 118               Veiled Shade             Gravitic Punch
# 119               Izzet Locket           Moodmark Painter
# 120        Watcher in the Mist       Tajic, Legion's Edge
# 121             Wee Dragonauts        Piston-Fist Cyclops
# 122           League Guildmage           League Guildmage
# 123                Beacon Bolt                Beacon Bolt
# 124            Izzet Guildgate              Hypothesizzle
# 125              Hypothesizzle         Nightveil Predator
# 126               Radical Idea               Radical Idea
# 127            Izzet Guildgate            Izzet Guildgate
# 128          Inescapable Blaze          Inescapable Blaze
# 129            Izzet Guildgate            Izzet Guildgate
# 130  Unexplained Disappearance  Unexplained Disappearance
# 131              Wishcoin Crab           Grappling Sundew
# 132            Izzet Guildgate            Izzet Guildgate
# 133          Garrison Sergeant          Garrison Sergeant
# 134            Selesnya Locket            Selesnya Locket

# %%
df.iloc[135:180]
# Out:
#                                                                                                                                                                                                                                                                           options  \
# 135                   [Beacon Bolt, Generous Stray, Rubblebelt Boar, Never Happened, Boros Locket, Rosemane Centaur, Dimir Informant, Cosmotronic Wave, Sumala Woodshaper, Vedalken Mesmerist, Devkarin Dissident, Street Riot, Nightveil Predator, Camaraderie, Boros Guildgate]
# 136                            [Roc Charger, Burglar Rat, Barrier of Bones, Vedalken Mesmerist, Centaur Peacemaker, Severed Strands, Vernadi Shieldmate, Pack's Favor, Crushing Canopy, Command the Storm, Urban Utopia, Inescapable Blaze, Undercity Necrolisk, Dimir Guildgate]
# 137                                      [Deafening Clarion, Urban Utopia, Torch Courier, Pause for Reflection, Bartizan Bats, Centaur Peacemaker, Passwall Adept, Capture Sphere, Tenth District Guard, Garrison Sergeant, Hellkite Whelp, Arboretum Elemental, Boros Guildgate]
# 216                                                                                                          [Parhelion Patrol, Direct Current, Rubblebelt Boar, Devious Cover-Up, Wall of Mist, Severed Strands, Golgari Locket, Crush Contraband, Selesnya Guildgate]
# 217                                                                                                                     [Hellkite Whelp, Dimir Locket, Vedalken Mesmerist, Wishcoin Crab, Candlelight Vigil, Barrier of Bones, Disdainful Stroke, Pause for Reflection]
# 218                                                                                                                                                       [Leapfrog, Dazzling Lights, Goblin Locksmith, Barrier of Bones, Maniacal Rage, Bounty Agent, Izzet Guildgate]
# 219                                                                                                                                                                      [Rubblebelt Boar, Sure Strike, Muse Drake, Wishcoin Crab, Worldsoul Colossus, Izzet Guildgate]
# 220                                                                                                                                                                [Sure Strike, Collar the Culprit, Pause for Reflection, Vedalken Mesmerist, Disinformation Campaign]
# 221                                                                                                                                                                                             [Maniacal Rage, Enhanced Surveillance, Hammer Dropper, Boros Guildgate]
# 222                                                                                                                                                                                                                [Disdainful Stroke, Candlelight Vigil, Dimir Locket]
# 223                                                                                                                                                                                                                              [Passwall Adept, Pause for Reflection]
# 224                                                                                                                                                                                                                                                      [Wall of Mist]
#
#                      predicted                      taken
# 180      Vraska, Golgari Queen      Vraska, Golgari Queen
# 181           Citywatch Sphinx           Citywatch Sphinx
# 182              Whisper Agent              Whisper Agent
# 183       Tajic, Legion's Edge          Command the Storm
# 184           Boros Challenger           Boros Challenger
# 185             Luminous Bonds             Luminous Bonds
# 186           Ironshell Beetle              Sonic Assault
# 187          Inescapable Blaze          Inescapable Blaze
# 188             Justice Strike             Hellkite Whelp
# 189  Unexplained Disappearance               Izzet Locket
# 190              Ornery Goblin          Garrison Sergeant
# 191               Radical Idea               Wall of Mist
# 192           Cosmotronic Wave               Boros Locket
# 193              Maniacal Rage             Gravitic Punch
# 194              Maniacal Rage              Maniacal Rage
# 195               Dawn of Hope            Boros Guildgate
# 196           Murmuring Mystic          Deafening Clarion
# 197              Ornery Goblin              Ornery Goblin
# 198        Piston-Fist Cyclops        Piston-Fist Cyclops
# 199           Barging Sergeant           Parhelion Patrol
# 200       Goblin Electromancer                 Narcomoeba
# 201            Boros Guildgate            Boros Guildgate
# 202         Vernadi Shieldmate  Unexplained Disappearance
# 203        Piston-Fist Cyclops            Dimir Informant
# 204            Izzet Guildgate            Izzet Guildgate
# 205           Cosmotronic Wave           Crush Contraband
# 206               Wall of Mist               Wall of Mist
# 207           Cosmotronic Wave           Cosmotronic Wave
# 208            Mephitic Vapors            Mephitic Vapors
# 209           Barrier of Bones           Barrier of Bones
# 210        Chemister's Insight             Justice Strike
# 211            Izzet Guildgate           Boros Challenger
# 212                Risk Factor                Risk Factor
# 213          Runaway Steam-Kin          Runaway Steam-Kin
# 214       Goblin Electromancer             Capture Sphere
# 215      Skyknight Legionnaire      Skyknight Legionnaire
# 216             Direct Current           Parhelion Patrol
# 217          Disdainful Stroke             Hellkite Whelp
# 218            Izzet Guildgate                   Leapfrog
# 219            Izzet Guildgate            Rubblebelt Boar
# 220                Sure Strike                Sure Strike
# 221            Boros Guildgate              Maniacal Rage
# 222          Disdainful Stroke          Disdainful Stroke
# 223             Passwall Adept             Passwall Adept
# 224               Wall of Mist               Wall of Mist
